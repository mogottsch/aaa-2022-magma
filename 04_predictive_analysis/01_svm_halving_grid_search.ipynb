# %%
from time import time
import pandas as pd

# for model training
from sklearn.svm import SVR

# for evaluation & preprocessing
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import (
    train_test_split,
    GridSearchCV,
    HalvingGridSearchCV,
)
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    mean_squared_error,
    mean_absolute_error,
)
import sys, os
sys.path.append(os.path.abspath(os.path.join("..")))

# for displaying results & feedback
# from tabulate import tabulate
import matplotlib.pyplot as plt

# %%
import sys, os

sys.path.append(os.path.abspath('..'))
# %load_ext autoreload
# %autoreload 2
from modules.config import *

# %%
model_data = pd.read_parquet(MODEL_DATA_PATH)
model_data.head(2)
# Out:
#       start_hex_id       end_hex_id  demand  time_interval_length  hour_0  \
# 0  871f1a164ffffff  871f1a164ffffff       1                     1       1
# 1  871f1a164ffffff  871f1a164ffffff       1                     1       1
#
#    hour_1  hour_2  hour_3  hour_4  hour_5  ...  public_transport_poi_start  \
# 0       0       0       0       0       0  ...                         503
# 1       0       0       0       0       0  ...                         503
#
#    education_poi_start  arts_and_culture_poi_start  sports_poi_start  h3_res  \
# 0                  101                          40                45       7
# 1                  101                          40                45       7
#
#    sustenance_poi_end  public_transport_poi_end  education_poi_end  \
# 0                 862                       503                101
# 1                 862                       503                101
#
#    arts_and_culture_poi_end  sports_poi_end
# 0                        40              45
# 1                        40              45
#
# [2 rows x 64 columns]

# %%
# encode start and end hexagons as one-hot vectors
model_data = model_data[(model_data['h3_res'] == 7) & (model_data['time_interval_length'] == 24)]
start_hex_dummies = pd.get_dummies(model_data.start_hex_id, prefix="start_")
end_hex_dummies = pd.get_dummies(model_data.end_hex_id, prefix="end_")
model_data = pd.concat([model_data, start_hex_dummies, end_hex_dummies], axis=1)
model_data = model_data.drop(columns=['start_hex_id', 'end_hex_id'])

# %%
len(model_data.index)
# Out:
# 921849

# %%
model_data = model_data.iloc[:50000]

# %%
y = model_data["demand"]
X = model_data.drop(columns=["demand"])

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42)

print(f"Size of the train dataset is: {X_train.shape[0]}")
print(f"Size of the test dataset is: {X_test.shape[0]}")
# Out:
# Size of the train dataset is: 35000
# Size of the test dataset is: 15000

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
def mean_average_percentage_error(y_true, y_pred):
    return mean_absolute_error(y_true, y_pred) / y_true.mean()


def root_mean_squared_error(y_true, y_pred):
    return mean_squared_error(y_true, y_pred) ** 0.5

# %%
param_grid = [
  {'kernel': ['linear'], 'C': [1, 10, 100]},
  {'kernel': ['rbf'], 'C': [1, 10, 100], 'gamma': [0.001, 0.0001]},
  {'kernel': ['poly'], 'C': [1, 10, 100], 'degree': [2, 3, 4, 5]}
 ]
svr = SVR()
clf = HalvingGridSearchCV(svr, param_grid, n_jobs=-1, scoring="neg_mean_squared_error", random_state=42)
clf.fit(X_train, y_train)
# Out:
# HalvingGridSearchCV(estimator=SVR(), n_jobs=-1,
#                     param_grid=[{'C': [1, 10, 100], 'kernel': ['linear']},
#                                 {'C': [1, 10, 100], 'gamma': [0.001, 0.0001],
#                                  'kernel': ['rbf']},
#                                 {'C': [1, 10, 100], 'degree': [2, 3, 4, 5],
#                                  'kernel': ['poly']}],
#                     random_state=42, scoring='neg_mean_squared_error')

# %%
results = pd.DataFrame(clf.cv_results_)
results.sort_values(by="mean_test_score", ascending=False).head(5)
# Out:
#     iter  n_resources  mean_fit_time  std_fit_time  mean_score_time  \
# 30     2        34992     804.191074     84.796919        47.307169
# 29     2        34992    1106.830871     60.876727        35.828149
# 26     1        11664      32.063715      6.620148         4.276786
# 27     1        11664      31.889680      1.653201         3.444474
# 28     2        34992    3053.402636    183.363885        16.660356
#
#     std_score_time param_C param_kernel param_gamma param_degree  ...  \
# 30        2.693901     100         poly         NaN            5  ...
# 29        3.590523     100         poly         NaN            4  ...
# 26        0.867433     100         poly         NaN            5  ...
# 27        1.182337     100         poly         NaN            4  ...
# 28        1.789491     100         poly         NaN            3  ...
#
#    mean_test_score  std_test_score  rank_test_score  split0_train_score  \
# 30       -2.654826        0.455459                1           -2.250397
# 29       -5.678539        0.703346                2           -4.798248
# 26      -16.923292        2.328463                3           -9.870120
# 27      -24.259991        3.613449                4          -14.275176
# 28      -44.632951        1.152993                5          -40.710521
#
#     split1_train_score  split2_train_score  split3_train_score  \
# 30           -2.107887           -1.953211           -2.334988
# 29           -4.713985           -4.643493           -4.728365
# 26           -9.524108           -8.759425           -9.151650
# 27          -14.664830          -14.113496          -14.692955
# 28          -40.936003          -39.848274          -39.847225
#
#     split4_train_score  mean_train_score  std_train_score
# 30           -2.411238         -2.211544         0.163772
# 29           -4.707741         -4.718366         0.049435
# 26           -8.341473         -9.129355         0.540863
# 27          -13.756395        -14.300570         0.351687
# 28          -39.969499        -40.262304         0.465664
#
# [5 rows x 26 columns]

# %%
y_pred = clf.best_estimator_.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_average_percentage_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)

print(f"MSE: {mse}")
print(f"MAE: {mae}")
print(f"MAPE: {mape}")
print(f"RMSE: {rmse}")
# Out:
# MSE: 1.7919743465746079
# MAE: 0.2095090314897931
# MAPE: 0.005517780749168895
# RMSE: 1.3386464606364923

# %%
pd.Series(y_pred).describe()
# Out:
# count    15000.000000
# mean        37.945909
# std         33.676102
# min          0.899873
# 25%         12.899903
# 50%         28.100005
# 75%         51.099998
# max        193.899954
# dtype: float64
